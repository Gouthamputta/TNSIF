# %% [markdown]
# <a href="https://colab.research.google.com/github/Gouthamputta/TNSIF/blob/main/Functions_and_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Function Without Parameters and Without Return Value**

# %%
def display():
    print("Hello World")
display()
# Out:
# Hello World

# %% [markdown]
# Function With Parameters

# %%
def greet(name):
    print("Hello", name)

greet("Goutham")
greet("Max")
# Out:
# Hello Goutham
# Hello Max

# %% [markdown]
# Function With Return Value

# %%
def add(a,b):
    return a*b

result=add(3,12)
print(result)
# Out:
# 36

# %% [markdown]
# Function With Parameters and Return Value

# %%
def square(n):
    return n*n

result=square(9)
print(result)
# Out:
# 81

# %% [markdown]
# Lambda Function

# %%
multiply=lambda a, b: a * b
print(multiply(5,2))
# Out:
# 10

# %% [markdown]
# Classes in Python

# %%
class Person:
   name="Goutham"
a=Person()
print(a.name)
# Out:
# Goutham

# %% [markdown]
# Constructor Class in Python

# %%
class student:

  def __init__(self,name,age):
    self.name = name
    self.age = age
s1 = student("Goutham",22)

print("Name :",s1.name)
print("Age :",s1.age)
# Out:
# Name : Goutham
# Age : 22

# %%
class student:
  def __init__(self,name):
    self.name = name

  def display(self):
    print("Name of the student: ",self.name)

s1 = student("Goutham")
s1.display()
# Out:
# Name of the student:  Goutham

# %%
class Family:
 def __init__(self,mother,father):
  self.mother=mother
  self.father=father

 def display(self):
  print("Mother:",self.mother)
  print("Father:",self.father)

f=Family("Sita","Ram")
f.display()
# Out:
# Mother: Sita
# Father: Ram

# %%
class Student:
 def __init__(self,name,marks):
  self.name=name
  self.marks=marks

 def display(self):
  if self.marks>=40:
   print(self.name,"Pass")
  else:
   print(self.name,"Fail")

s=Student("Goutham",95)
s.display()
# Out:
# Goutham Pass

# %%
class Employee:
 def __init__(self,name,salary):
  self.name=name
  self.salary=salary

 def display(self):
  if self.salary>50000:
   print(self.name,"High salary")
  else:
   print(self.name,"Low salary")

e=Employee("Priya",60000)
e.display()
# Out:
# Priya High salary
