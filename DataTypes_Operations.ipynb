# %% [markdown]
# <a href="https://colab.research.google.com/github/Gouthamputta/TNSIF/blob/main/DataTypes_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Goutham"
age=22
print("Name:",name)
print("Age:",age)
# Out:
# Name: Goutham
# Age: 22

# %% [markdown]
# Datatypes

# %%
name="Python"
age=21
percentage=12.3
boo=True
print(name)
print(age)
print(percentage)
print(boo)
print(type(name))
print(type(age))
print(type(percentage))
print(type(boo))
# Out:
# Python
# 21
# 12.3
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Operations-Arithmetic operators

# %%
a=10
b=2
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Floor Division:",a//b)
print("Modulus:",a%b)
print("Exponent:",a**b)
# Out:
# Addition: 12
# Subtraction: 8
# Multiplication: 20
# Division: 5.0
# Floor Division: 5
# Modulus: 0
# Exponent: 100

# %% [markdown]
# Comparison operators

# %%
a=9
b=4
print("Equal:",a==b)
print("Not Equal:",a!=b)
print("Greater Than:",a>b)
print("Less Than:",a<b)
print("Less Than or Equal:",a<=b)
# Out:
# Equal: False
# Not Equal: True
# Greater Than: True
# Less Than: False
# Less Than or Equal: False

# %% [markdown]
# Assignment operators

# %%
a=6
a+=3
print("+= :",a)
a-=3
print("-= :",a)
a*=4
print("*= :",a)
a/=4
print("/= :",a)
a%=3
print("%= :",a)
a**=2
print("**= :",a)
# Out:
# += : 9
# -= : 6
# *= : 24
# /= : 6.0
# %= : 0.0
# **= : 0.0

# %% [markdown]
# Logical operators

# %%
a=6
b=5
print("AND:",a>5 and b<10)
print("OR:",a<5 or b<10)
print("NOT:",not(a<5))
# Out:
# AND: True
# OR: True
# NOT: True

# %% [markdown]
# Bitwise operators

# %%
a=6
b=2
print(a and b)
print(a or b)
print(a^b)
print(~a)
print(a>>2)
print(a<<2)
# Out:
# 2
# 6
# 4
# -7
# 1
# 24
